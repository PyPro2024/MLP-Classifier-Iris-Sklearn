# %% [markdown]
# ***Tutorial 2***

# %%
# Step 1 Importing Required Libraries
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report,accuracy_score

# Step 2 Loading and Splitting the Iris Dataset
iris = load_iris()
X = iris.data # Features
y = iris.target # Labels
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 3 Data Scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train) #Fit on training data and transform
X_test_scaled = scaler.transform(X_test) # Transform test data (using same scaling)

# Step 4 Creating and Training the MLP Classifier
mlp = MLPClassifier(hidden_layer_sizes=(10, 10), max_iter=1000, random_state=42,learning_rate_init=0.001) # MLPclassifier contains 2 hidden layers with 10 neurons in each
mlp.fit(X_train_scaled, y_train)

# Step 5 Making Predictions and Evaluating the Model
y_pred = mlp.predict(X_test_scaled)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))

# Step 6 Displaying the MLP Structure and Training Information
print('\nMLP Structures:')
print("Number of layers:", mlp.n_layers_)
print("Number of outputs:", mlp.n_outputs_)
print("Activation function:", mlp.activation)
print('Output activation funtion:', mlp.out_activation_)
print("Number of iterations (epochs):", mlp.n_iter_)

# Step 7  Visualizing the Learning Curve (Loss Curve)
plt.figure(figsize=(8, 6))
plt.plot(mlp.loss_curve_, label='Training Loss')
plt.title("MLP Classifier Learning Curve")
plt.xlabel("Epocs")
plt.ylabel("Loss")
plt.legend()
plt.grid()
plt.show()
# Out:
# Accuracy: 1.0
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
#
#
# MLP Structures:
# Number of layers: 4
# Number of outputs: 3
# Activation function: relu
# Output activation funtion: softmax
# Number of iterations (epochs): 609

# %% [markdown]
# ***Task 1 Modification of MLP Model***
#
# ---

# %%
# Step 1 Importing Required Libraries
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report,accuracy_score

# Step 2 Loading and Splitting the Iris Dataset
iris = load_iris()
X = iris.data # Features
y = iris.target # Labels
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 3 Data Scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train) #Fit on training data and transform
X_test_scaled = scaler.transform(X_test) # Transform test data (using same scaling)

'''Step 4 Modifying the MLP Classifier''' # by changing the num of hidden layers and neurons
mlp = MLPClassifier(hidden_layer_sizes=(4), max_iter=1000, random_state=42,learning_rate_init=0.001)
mlp.fit(X_train_scaled, y_train)

# Step 5 Making Predictions and Evaluating the Model
y_pred = mlp.predict(X_test_scaled)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))

# Step 6 Displaying the MLP Structure and Training Information
print('\nMLP Structures:')
print("Number of layers:", mlp.n_layers_)
print("Number of outputs:", mlp.n_outputs_)
print("Activation function:", mlp.activation)
print('Output activation funtion:', mlp.out_activation_)
print("Number of iterations (epochs):", mlp.n_iter_)

# Step 7  Visualizing the Learning Curve (Loss Curve)
plt.figure(figsize=(8, 6))
plt.plot(mlp.loss_curve_, label='Training Loss')
plt.title("MLP Classifier Learning Curve")
plt.xlabel("Epocs")
plt.ylabel("Loss")
plt.legend()
plt.grid()
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Accuracy: 1.0
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
#
#
# MLP Structures:
# Number of layers: 3
# Number of outputs: 3
# Activation function: relu
# Output activation funtion: softmax
# Number of iterations (epochs): 1000

# %% [markdown]
# TASK1 Result: By changing the num of hidden layers between 1-4 and neurons between 5-25 the accuracy remained same, while before 5 & after 25 num of neurons the accuracy changed.

# %% [markdown]
# ***Task2 Changing the Learning Rate of MLP***
#
# ---

# %%
# Step 1 Importing Required Libraries
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report,accuracy_score

# Step 2 Loading and Splitting the Iris Dataset
iris = load_iris()
X = iris.data # Features
y = iris.target # Labels
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 3 Data Scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train) #Fit on training data and transform
X_test_scaled = scaler.transform(X_test) # Transform test data (using same scaling)

# Step 4 Creating and Training the MLP Classifier
mlp = MLPClassifier(hidden_layer_sizes=(10, 10), max_iter=1000, random_state=42,learning_rate_init=0.01)
mlp.fit(X_train_scaled, y_train)

# Step 5 Making Predictions and Evaluating the Model
y_pred = mlp.predict(X_test_scaled)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))

# Step 6 Displaying the MLP Structure and Training Information
print('\nMLP Structures:')
print("Number of layers:", mlp.n_layers_)
print("Number of outputs:", mlp.n_outputs_)
print("Activation function:", mlp.activation)
print('Output activation funtion:', mlp.out_activation_)
print("Number of iterations (epochs):", mlp.n_iter_)

# Step 7  Visualizing the Learning Curve (Loss Curve)
plt.figure(figsize=(8, 6))
plt.plot(mlp.loss_curve_, label='Training Loss')
plt.title("MLP Classifier Learning Curve")
plt.xlabel("Epocs")
plt.ylabel("Loss")
plt.legend()
plt.grid()
plt.show()
# Out:
# Accuracy: 1.0
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
#
#
# MLP Structures:
# Number of layers: 4
# Number of outputs: 3
# Activation function: relu
# Output activation funtion: softmax
# Number of iterations (epochs): 157

# %% [markdown]
# At learning rate =0.01, the model converged quickly and smoothly. It reached high accuracy with 157 number of epochs. Therefore, it provided the best balance between convergence speed and model performance

# %% [markdown]
# At Learning rate=0.1 the loss curve was not smooth and sometimes failed to converge stably, because steps were too large. The epocs were 159.
# image ![image.png](data:image/png;base64,...)

# %% [markdown]
# At 0.0001 the epocs = 1000 while the model learned very slowly, often hitting the maximum iterations without full convergenc ![image.png](data:image/png;base64,...)
